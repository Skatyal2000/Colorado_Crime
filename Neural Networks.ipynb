# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score, recall_score, f1_score, precision_recall_curve, roc_curve

# %%
df = pd.read_csv('AreaData.csv')

# %%
df
# Out:
#      arrest_date  pd_cd                                     pd_desc  \
# 0     2017-10-29  139.0                         MURDER,UNCLASSIFIED
# 1     2010-09-24  809.0                                     TAX LAW
# 2     2015-07-29  760.0               BRIBERY,PUBLIC ADMINISTRATION
# 3     2007-05-09  439.0  LARCENY,GRAND FROM OPEN AREAS,UNCLASSIFIED
# 4     2017-08-11  101.0                                   ASSAULT 3
# ...          ...    ...                                         ...
# 5461  2015-11-14  109.0                    ASSAULT 2,1,UNCLASSIFIED
# 5462  2018-07-03  439.0  LARCENY,GRAND FROM OPEN AREAS,UNCLASSIFIED
# 5463  2015-05-05  478.0             THEFT OF SERVICES, UNCLASSIFIED
# 5464  2006-06-23  905.0                 INTOXICATED DRIVING,ALCOHOL
# 5465  2011-06-16  490.0                STOLEN PROPERTY 3,POSSESSION
#
#         law_code law_cat_cd arrest_boro  arrest_precinct  jurisdiction_code  \
# 0     PL 1252501          F           M               13                0.0
# 1     TAX1817000          M           B               52                0.0
# 2     PL 2154002          F           K               71                0.0
# 3     PL 1553500          F           B               45                0.0
# 4     PL 1200001          M           S              120                0.0
# ...          ...        ...         ...              ...                ...
# 5461  PL 1200501          F           K               83                0.0
# 5462  PL 1553001          F           K               84                0.0
# 5463  PL 1651503          M           Q              112                0.0
# 5464  VTL11920M2          M           M               10                0.0
# 5465  PL 1654000          M           M               14                0.0
#
#      age_group perp_sex                 perp_race  x_coord_cd  y_coord_cd  \
# 0        25-44        M                     BLACK    988972.0    207813.0
# 1        45-64        M                     BLACK   1013888.0    253284.0
# 2        18-24        M                     BLACK    998007.0    179260.0
# 3        25-44        M            BLACK HISPANIC   1032140.0    242004.0
# 4        25-44        M  ASIAN / PACIFIC ISLANDER    950012.0    162645.0
# ...        ...      ...                       ...         ...         ...
# 5461     25-44        F            WHITE HISPANIC   1006376.0    192043.0
# 5462     25-44        M                     BLACK    989003.0    192413.0
# 5463     18-24        M                     BLACK   1031029.0    199612.0
# 5464     18-24        M  ASIAN / PACIFIC ISLANDER    985110.0    215630.0
# 5465     25-44        F                     BLACK    989613.0    213913.0
#
#        latitude  longitude  arrest_year  \
# 0     40.737082 -73.982962         2017
# 1     40.861839 -73.892853         2010
# 2     40.658702 -73.950418         2015
# 3     40.830799 -73.826949         2007
# 4     40.613041 -74.123318         2017
# ...         ...        ...          ...
# 5461  40.693771 -73.920213         2015
# 5462  40.694813 -73.982861         2018
# 5463  40.714450 -73.831259         2015
# 5464  40.758539 -73.996897         2006
# 5465  40.753825 -73.980644         2011
#
#                                               area_name
# 0     221, East 21st Street, Gramercy, Manhattan Com...
# 1     2514, Marion Avenue, Fordham, Bronx County, Th...
# 2     1177, Nostrand Avenue, Brooklyn Community Dist...
# 3     2899, Barkley Avenue, Schuylerville, Bronx Cou...
# 4     1800, Victory Boulevard, Castleton Corners, St...
# ...                                                 ...
# 5461  119, Grove Street, Brooklyn, Kings County, Cit...
# 5462  176, Johnson Street, Brooklyn Navy Yard, Brook...
# 5463  Kew Gardens-Union Turnpike (E,F), 80th Road, K...
# 5464  West 40th Street, Hell's Kitchen, Manhattan, N...
# 5465  510, 5th Avenue, Manhattan Community Board 5, ...
#
# [5466 rows x 17 columns]

# %%
df['pin_code'] = df['area_name'].str.extract(r'(\b\d{5}\b)')

# %%
df['pin_code'] = pd.to_numeric(df['pin_code'], errors='coerce')

# %%
df.head()
# Out:
#   arrest_date  pd_cd                                     pd_desc    law_code  \
# 0  2017-10-29  139.0                         MURDER,UNCLASSIFIED  PL 1252501
# 1  2010-09-24  809.0                                     TAX LAW  TAX1817000
# 2  2015-07-29  760.0               BRIBERY,PUBLIC ADMINISTRATION  PL 2154002
# 3  2007-05-09  439.0  LARCENY,GRAND FROM OPEN AREAS,UNCLASSIFIED  PL 1553500
# 4  2017-08-11  101.0                                   ASSAULT 3  PL 1200001
#
#   law_cat_cd arrest_boro  arrest_precinct  jurisdiction_code age_group  \
# 0          F           M               13                0.0     25-44
# 1          M           B               52                0.0     45-64
# 2          F           K               71                0.0     18-24
# 3          F           B               45                0.0     25-44
# 4          M           S              120                0.0     25-44
#
#   perp_sex                 perp_race  x_coord_cd  y_coord_cd   latitude  \
# 0        M                     BLACK    988972.0    207813.0  40.737082
# 1        M                     BLACK   1013888.0    253284.0  40.861839
# 2        M                     BLACK    998007.0    179260.0  40.658702
# 3        M            BLACK HISPANIC   1032140.0    242004.0  40.830799
# 4        M  ASIAN / PACIFIC ISLANDER    950012.0    162645.0  40.613041
#
#    longitude  arrest_year                                          area_name  \
# 0 -73.982962         2017  221, East 21st Street, Gramercy, Manhattan Com...
# 1 -73.892853         2010  2514, Marion Avenue, Fordham, Bronx County, Th...
# 2 -73.950418         2015  1177, Nostrand Avenue, Brooklyn Community Dist...
# 3 -73.826949         2007  2899, Barkley Avenue, Schuylerville, Bronx Cou...
# 4 -74.123318         2017  1800, Victory Boulevard, Castleton Corners, St...
#
#    pin_code
# 0   10010.0
# 1   10458.0
# 2   11225.0
# 3   10465.0
# 4   10314.0

# %%
df2 = df.drop(columns = ['arrest_date','area_name','x_coord_cd','y_coord_cd','latitude','longitude'])

# %%
df2['pd_desc'] = df2['pd_desc'].str.split().str.get(0)

# %%
df2['law_code'] = df2['law_code'].str[:3]

# %%
desc_value_counts = df2['pin_code'].value_counts()
values_to_remove = desc_value_counts[desc_value_counts < 20].index
df2 = df2[~df2['pin_code'].isin(values_to_remove)]

# %%
col = ['pd_desc','law_code', 'pd_cd','jurisdiction_code']
for i in col:
    desc_value_counts = df2[i].value_counts()
    values_to_remove = desc_value_counts[desc_value_counts < 5].index
    df2 = df2[~df2[i].isin(values_to_remove)]

# %%
df2
# Out:
#       pd_cd              pd_desc law_code law_cat_cd arrest_boro  \
# 0     139.0  MURDER,UNCLASSIFIED      PL           F           M
# 1     809.0                  TAX      TAX          M           B
# 2     760.0       BRIBERY,PUBLIC      PL           F           K
# 3     439.0        LARCENY,GRAND      PL           F           B
# 4     101.0              ASSAULT      PL           M           S
# ...     ...                  ...      ...        ...         ...
# 5459  101.0              ASSAULT      PL           M           B
# 5461  109.0              ASSAULT      PL           F           K
# 5462  439.0        LARCENY,GRAND      PL           F           K
# 5464  905.0          INTOXICATED      VTL          M           M
# 5465  490.0               STOLEN      PL           M           M
#
#       arrest_precinct  jurisdiction_code age_group perp_sex  \
# 0                  13                0.0     25-44        M
# 1                  52                0.0     45-64        M
# 2                  71                0.0     18-24        M
# 3                  45                0.0     25-44        M
# 4                 120                0.0     25-44        M
# ...               ...                ...       ...      ...
# 5459               46                0.0     45-64        F
# 5461               83                0.0     25-44        F
# 5462               84                0.0     25-44        M
# 5464               10                0.0     18-24        M
# 5465               14                0.0     25-44        F
#
#                      perp_race  arrest_year  pin_code
# 0                        BLACK         2017   10010.0
# 1                        BLACK         2010   10458.0
# 2                        BLACK         2015   11225.0
# 3               BLACK HISPANIC         2007   10465.0
# 4     ASIAN / PACIFIC ISLANDER         2017   10314.0
# ...                        ...          ...       ...
# 5459            BLACK HISPANIC         2008   10457.0
# 5461            WHITE HISPANIC         2015   11221.0
# 5462                     BLACK         2018   11201.0
# 5464  ASIAN / PACIFIC ISLANDER         2006   10018.0
# 5465                     BLACK         2011   10035.0
#
# [4514 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

for i in df2.columns:
    df2[i] = label.fit_transform(df2[i])

# %%
y = df2[['jurisdiction_code']]
x = df2.drop(columns = ['jurisdiction_code'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
cla = Sequential()

# %%
cla.add(Dense(units=8, activation='relu'))
cla.add(Dense(units=1,activation='sigmoid'))

# %%
cla.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
cla.fit(X_train, y_train, epochs=150, batch_size=25)
# Out:
# Epoch 1/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 1s 411us/step - accuracy: 0.7194 - loss: 3.1652
# Epoch 2/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - accuracy: 0.5053 - loss: 1.5503
# Epoch 3/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - accuracy: 0.6096 - loss: 0.9972
# Epoch 4/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - accuracy: 0.6454 - loss: 0.8450
# Epoch 5/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - accuracy: 0.6801 - loss: 0.8042
# Epoch 6/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - accuracy: 0.6871 - loss: 0.6949
# Epoch 7/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - accuracy: 0.6780 - loss: 0.6761
# Epoch 8/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 314us/step - accuracy: 0.6861 - loss: 0.6462
# Epoch 9/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - accuracy: 0.7309 - loss: 0.6281
# Epoch 10/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - accuracy: 0.6856 - loss: 0.6599
# Epoch 11/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - accuracy: 0.7254 - loss: 0.6178
# Epoch 12/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - accuracy: 0.7115 - loss: 0.6074
# Epoch 13/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - accuracy: 0.6697 - loss: 0.6248
# Epoch 14/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - accuracy: 0.7337 - loss: 0.5987
# Epoch 15/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - accuracy: 0.6749 - loss: 0.6256
# Epoch 16/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - accuracy: 0.7095 - loss: 0.6077
# Epoch 17/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - accuracy: 0.7309 - loss: 0.6113
# Epoch 18/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - accuracy: 0.7642 - loss: 0.5584
# Epoch 19/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 310us/step - accuracy: 0.7514 - loss: 0.5807
# Epoch 20/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step - accuracy: 0.6609 - loss: 0.6210
# Epoch 21/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - accuracy: 0.7415 - loss: 0.6079
# Epoch 22/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - accuracy: 0.7130 - loss: 0.6191
# Epoch 23/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - accuracy: 0.7165 - loss: 0.5844
# Epoch 24/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - accuracy: 0.7064 - loss: 0.5702
# Epoch 25/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.7374 - loss: 0.5986
# Epoch 26/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - accuracy: 0.6566 - loss: 0.6392
# Epoch 27/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - accuracy: 0.6724 - loss: 0.6277
# Epoch 28/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - accuracy: 0.7152 - loss: 0.6134
# Epoch 29/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - accuracy: 0.7058 - loss: 0.6019
# Epoch 30/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - accuracy: 0.
150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - accuracy: 0.7526 - loss: 0.5048
# Epoch 99/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - accuracy: 0.7507 - loss: 0.4063
# Epoch 100/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.7395 - loss: 0.5845
# Epoch 101/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - accuracy: 0.7414 - loss: 0.5421
# Epoch 102/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - accuracy: 0.7398 - loss: 0.5205
# Epoch 103/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - accuracy: 0.7539 - loss: 0.5165
# Epoch 104/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - accuracy: 0.7301 - loss: 0.5167
# Epoch 105/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - accuracy: 0.7186 - loss: 0.5266
# Epoch 106/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - accuracy: 0.7163 - loss: 0.5437
# Epoch 107/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step - accuracy: 0.7140 - loss: 0.5456
# Epoch 108/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - accuracy: 0.7267 - loss: 0.5465
# Epoch 109/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - accuracy: 0.7395 - loss: 0.5094
# Epoch 110/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 313us/step - accuracy: 0.7556 - loss: 0.5406
# Epoch 111/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - accuracy: 0.7430 - loss: 0.5432
# Epoch 112/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 345us/step - accuracy: 0.7477 - loss: 0.5019
# Epoch 113/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 321us/step - accuracy: 0.6587 - loss: 0.5949
# Epoch 114/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7379 - loss: 0.5705
# Epoch 115/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - accuracy: 0.6824 - loss: 0.5881
# Epoch 116/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 402us/step - accuracy: 0.7258 - loss: 0.5360
# Epoch 117/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - accuracy: 0.7411 - loss: 0.4809
# Epoch 118/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - accuracy: 0.7367 - loss: 0.5373
# Epoch 119/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - accuracy: 0.7503 - loss: 0.4014
# Epoch 120/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 357us/step - accuracy: 0.7438 - loss: 0.4803
# Epoch 121/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - accuracy: 0.7013 - loss: 0.5693
# Epoch 122/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 316us/step - accuracy: 0.7517 - loss: 0.5602
# Epoch 123/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.7570 - loss: 0.5254
# Epoch 124/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - accuracy: 0.6997 - loss: 0.4117
# Epoch 125/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step - accuracy: 0.7213 - loss: 0.4839
# Epoch 126/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.7355 - loss: 0.4997
# Epoch 127/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - accuracy: 0.7345 - loss: 0.3955
# Epoch 128/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - accuracy: 0.7289 - loss: 0.4980
# Epoch 129/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - accuracy: 0.7219 - loss: 0.3184
# Epoch 130/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - accuracy: 0.7406 - loss: 0.5113
# Epoch 131/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step - accuracy: 0.7090 - loss: 0.5439
# Epoch 132/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step - accuracy: 0.7379 - loss: 0.5235
# Epoch 133/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 318us/step - accuracy: 0.7520 - loss: 0.5465
# Epoch 134/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - accuracy: 0.7325 - loss: 0.5296
# Epoch 135/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - accuracy: 0.6982 - loss: 0.4769
# Epoch 136/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 317us/step - accuracy: 0.7275 - loss: 0.5542
# Epoch 137/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 325us/step - accuracy: 0.7481 - loss: 0.5381
# Epoch 138/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - accuracy: 0.7123 - loss: 0.4521
# Epoch 139/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 315us/step - accuracy: 0.7336 - loss: 0.2686
# Epoch 140/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 323us/step - accuracy: 0.7106 - loss: 0.5619
# Epoch 141/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 322us/step - accuracy: 0.6969 - loss: 0.5338
# Epoch 142/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - accuracy: 0.7615 - loss: 0.4121
# Epoch 143/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - accuracy: 0.6977 - loss: 0.5208
# Epoch 144/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - accuracy: 0.6949 - loss: 0.4399
# Epoch 145/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - accuracy: 0.7580 - loss: 0.3872
# Epoch 146/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - accuracy: 0.7359 - loss: 0.5076
# Epoch 147/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - accuracy: 0.7283 - loss: 0.5104
# Epoch 148/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - accuracy: 0.7243 - loss: 0.4328
# Epoch 149/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - accuracy: 0.7199 - loss: 0.3920
# Epoch 150/150
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 324us/step - accuracy: 0.7489 - loss: 0.4879

# %%
y_pred = cla.predict(X_test)
y_pred_binary = [1 if pred > 0.5 else 0 for pred in y_pred]
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step

# %%
accuracy = accuracy_score(y_test, y_pred_binary)
accuracy
# Out:
# 0.7909654561558902

# %%
precision = precision_score(y_test, y_pred_binary, average='weighted')
recall = recall_score(y_test, y_pred_binary, average='weighted')
f1 = f1_score(y_test, y_pred_binary, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Precision: 0.7776709207532946
# Recall: 0.7909654561558902
# F1 Score: 0.7823046340061187
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
cdt = confusion_matrix(y_test.values, y_pred_binary)
plt.figure(figsize=(8, 6))
sns.heatmap(cdt, annot=True, fmt="d", cmap="YlGnBu")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Neural Network')
plt.show()
